# %%
# DO NOT MODIFY THIS CELL
# Imports libraries, to install, use 'pip install <package name>
import pandas as pd
import numpy as np
import re
from pandas.api.types import is_numeric_dtype

# Defines Functions
# Drops the index Column
def drop_index(df):
    if is_numeric_dtype(df.iloc[:, 0]):
        return (df.iloc[:, 1:])
    else:
        return df

# Cleans Phone Numbers
def clean_phone(number):
    # Convert to string and keep only digits
    digits = ''.join([char for char in str(number) if char.isdigit()])
    
    # Check if exactly 10 digits
    if len(digits) == 10:
        return f'({digits[:3]}){digits[3:6]}-{digits[6:]}'
    else:
        return np.nan

# Extracts emails
def extract_email(text):
    text = str(text)
    i = 0
    at_pos = text.find('@', i)
    if at_pos == -1:
        return np.nan
    dot_pos = text.find('.', at_pos)
    if dot_pos == -1:
        return np.nan
    if(dot_pos+4>len(text)):
        return np.nan
    return(text[0:(dot_pos+4)])

# Extracts contractor name, dropping anything with brackets
def extract_contractor(text):
    text = str(text)
    parts = text.split('(')
    for part in parts:
        return part
    return np.nan
    
# Extracts and cleans the address, correcting 'San Jose' spelled as 'San Josh'
def extract_address(text):
    text = pd.Series([text])
    new_text = text.str.replace("san josh", "San Jose", case = False, regex = True)
    new_text = new_text.str.replace('\n', '', regex = False)
    new_text = new_text.str.replace(r'\s*,\s*', ',', regex=True)
    new_text = new_text.str.replace(',', ', ', regex = False)
    return new_text

# Renames columns
def rename_columns_by_index(df, rename_dict):
    new_columns = df.columns.tolist()
    for idx, new_name in rename_dict.items():
        if 0 <= idx < len(new_columns):
            new_columns[idx] = new_name
    df.columns = new_columns
    return df

# Drops any data without valid phones or emials
def drop_rows_if_columns_blank(df, col_idx1, col_idx2):
    df = df.copy()
    # Replace empty strings with NaN for accurate detection
    df.replace('', pd.NA, inplace=True)
    
    # Drop rows where both specified columns are blank/NaN
    mask = df.iloc[:, col_idx1].isna() & df.iloc[:, col_idx2].isna()
    return df[~mask]

# Cleans Duplicates
def clean_duplicates(df):

    phone_dup = df.iloc[:,2].duplicated()
    df['phone_dup'] = phone_dup
    df = pd.concat([df, phone_dup])
    email_dup = df.iloc[:,3].duplicated() 
    df['email_dup'] = phone_dup
    df = pd.concat([df, email_dup])
    df = df[df['phone_dup']==False]
    df = df[df['email_dup']==False]
    df = df.drop(columns = 'phone_dup')
    df = df.drop(columns = 'email_dup')
    return df

# %%
# Additional Functions for Information about resulting data
# DO NOT MODIFY THIS CELL
# Prints business name frequency information
def find_names(df):
    total = df.shape[0]
    names = df.iloc[:,0]
    name_list = []
    for name in names:
        name_list.append(name.split())
    name_list_ind = []
    for i in name_list:
        for j in i:
            name_list_ind.append(j)
    name_list_values = {}

    # Find item frequencies dict
    for c in name_list_ind:
        #  in dictionary
        if c in name_list_values:
            name_list_values[c] += 1
        #  not in dictionary
        else:
            name_list_values[c] = 1

    # removes bad values
    bad_vals = ["Inc", 'Inc.', '&', 'Valley', 'Hill', 'Palo', 'Alto', 'SF', 'Morgan', 'Bay', 'Golden', 'Experts', 'Silicon', 'Gate', 'Area', 'Peninsula', 'and', 'Group', 'Crest', 'Co.', 'south']
    for i in bad_vals:
        if i in name_list_values:
            del name_list_values[i]
    
    sorted_items = sorted(name_list_values.items(), key=lambda kv: (kv[1], kv[0]), reverse = True)
    
    # Finds percentages
    #total = sum(count for word, count in sorted_items)
    # Convert to percentages
    percentages = [(word, count / total * 100) for word, count in sorted_items]
    # Round 
    percentages = [(word, round(pct, 2)) for word, pct in percentages]
    
    print('percentage of times each word occurs')
    print(percentages)
    print('number of times each word comes up')
    print (sorted_items)

# Prints locational information
def find_location(df):
    names = df.iloc[:,1]
    name_list = []
    for name in names:
        name_list.append(name.split())
    name_list_ind = []
    for i in name_list:
        for j in i:
            name_list_ind.append(j)
    name_list_values = {}

    # Find item frequencies dict
    for c in name_list_ind:
        #  in dictionary
        if c in name_list_values:
            name_list_values[c] += 1
        #  not in dictionary
        else:
            name_list_values[c] = 1

    # removes bad values
    bad_vals = ['CA', 'San', 'St,', 'Ave', 'Blvd', 'Ave,', 'Box,', 'PO', 'Box']
    for i in bad_vals:
        if i in name_list_values:
            del name_list_values[i]
    
    sorted_items = sorted(name_list_values.items(), key=lambda kv: (kv[1], kv[0]), reverse = True)

    print(sorted_items)

# %%
# Calls All functions
# DO NOT MODIFY THIS CELL
def data_cleaner(df, column_names, phone_column =2, email_column = 3):
    clean_data = df.copy()
    # cleans data
    clean_data = drop_index(clean_data)
    clean_data.iloc[:, 2] = clean_data.iloc[:, 2].apply(clean_phone)
    clean_data.iloc[:, 3] = clean_data.iloc[:, 3].apply(extract_email)
    clean_data.iloc[:, 0] = clean_data.iloc[:, 0].apply(extract_contractor)
    clean_data.iloc[:, 1] = clean_data.iloc[:, 1].apply(extract_address)
    clean_data = rename_columns_by_index(clean_data, column_names)
    clean_data = drop_rows_if_columns_blank(clean_data,phone_column,email_column)
    clean_data = clean_duplicates(clean_data)
    return clean_data

# %%
# Imports Excel Spreadsheet
# To import a new sheet, make sure it is in the same folder as this file
# Make sure the columns are in the order: Index(optional), customer name, address, phone number, email
# CHANGE THIS LINE
df = pd.read_excel('contact_info1.xlsx')

# %%
# Cleans data
# Change variables as needed

# Column names of the outputed sheet, feel free to change them as needed
column_names = {0:'Customer_Name', 1: 'Address', 2: 'Phone_Number', 3:'Email' }

# Calls function, and displays results, DO NOT CHANGE LINES BELOW
clean_data = df.copy()
clean_data = data_cleaner(clean_data, column_names)

# Prints out the Sheet information, and head
print("Sheet columns, rows:", clean_data.shape)
clean_data.head()
# Out:
# Sheet columns, rows: (79, 4)
#                                  Customer_Name  \
# 0                     MAI Construction , Inc .
# 1                       S O D home Group Inc.
# 2  construction Management Group Iternational
# 3              Green vision Construction Inc.
# 4                             Almaden Kitchen
#
#                                             Address   Phone_Number  \
# 0          50 Bonaventura drive, San Jose, CA 95134  (408)434-9880
# 1  367 Santana row, Unit 3-3021, San Jose, CA 95128  (800)401-3220
# 2             PO Box 20548, San Jose, CA 95160-1548  (408)273-6355
# 3                            San Jose, CA 951272413  (408)726-6578
# 4           2137 S 10th st, San Jose, CA 95112-4113  (408)292-0290
#
#                                Email
# 0             marketing@maiconst.com
# 1              info@sodhomegroup.com
# 2       contact@cmginternational.com
# 3  greenvisionconstruction@gmail.com
# 4            info@almadenkitchen.com

# %%
# Downloads the data as a CSV, and Excel. 
# Change the names inside the quotes to change the name of the file that will be created
# This will not work if a file with the intended name already exists.
# It should say download Complete if the new files where created
clean_contacts = clean_data.to_csv('clean_contacts.csv', index=False)
clean_contacts_xlx = clean_data.to_excel('clean_contacts.xlsx', index=False)
print('download complete')

# %%
# Optional: Gives some additional information about the sheet clean data
find_names(clean_data)
find_location(clean_data)
# Out:
# percentage of times each word occurs
# [('Construction', 30.38), ('Builders', 24.05), ('construction', 8.86), ('Renovators', 3.8), ('Home', 3.8), ('Build', 3.8), ('general', 2.53), ('design', 2.53), ('Renovations', 2.53), ('Modern', 2.53), ('General', 2.53), ('Design', 2.53), ('Country', 2.53), ('Contractors', 2.53), ('Contractor', 2.53), ('Builders,', 2.53), ('vision', 1.27), ('systems', 1.27), ('skyline', 1.27), ('pro', 1.27), ('home', 1.27), ('company', 1.27), ('builiding', 1.27), ('builder', 1.27), ('bay', 1.27), ('Yua', 1.27), ('Western', 1.27), ('West', 1.27), ('Welfring', 1.27), ('Vnace', 1.27), ('VMS', 1.27), ('Utopia', 1.27), ('Upgrades', 1.27), ('Uniluxe,', 1.27), ('Ulpio', 1.27), ('The', 1.27), ('Terry', 1.27), ('Sunrise', 1.27), ('Skyline', 1.27), ('Services', 1.27), ('S', 1.27), ('Roygbiv', 1.27), ('Renovation', 1.27), ('Remodeling', 1.27), ('Regel', 1.27), ('Redwood', 1.27), ('Rake', 1.27), ('Pro', 1.27), ('Prime', 1.27), ('Precision', 1.27), ('Power', 1.27), ('Plumbing', 1.27), ('Pacific', 1.27), ('One', 1.27), ('O', 1.27), ('Management', 1.27), ('MAI', 1.27), ('Lawjas', 1.27), ('Lacon', 1.27), ('LLC', 1.27), ('LK', 1.27), ('Kitchen', 1.27), ('Jimenez', 1.27), ('James', 1.27), ('J', 1.27), ('Iternational', 1.27), ('IBuilders', 1.27), ('Hua', 1.27), ('Homes', 1.27), ('Hilltop', 1.27), ('H', 1.27), ('Grid', 1.27), ('Grenon', 1.27), ('Green', 1.27), ('Giulani', 1.27), ('Gaylord', 1.27), ('Foundation', 1.27), ('Far', 1.27), ('Evergreen', 1.27), ('Energy', 1.27), ('Elite', 1.27), ('Dream', 1.27), ('Devcon', 1.27), ('Decor', 1.27), ('DI', 1.27), ('D', 1.27), ('Contracting', 1.27), ('Construction,', 1.27), ('Coastal', 1.27), ('Clarity', 1.27), ('Casa', 1.27), ('Caost', 1.27), ('Campisi', 1.27), ('Building', 1.27), ('Brown', 1.27), ('Brian', 1.27), ('Aria', 1.27), ('American', 1.27), ('Almaden', 1.27), ('All', 1.27), ('AZ', 1.27), ("AJ's", 1.27), ('ADG', 1.27), ('ABC', 1.27), ('AAA', 1.27), ('.', 1.27), ('-up', 1.27), (',', 1.27), ('&restoration', 1.27)]
# number of times each word comesup
# [('Construction', 24), ('Builders', 19), ('construction', 7), ('Renovators', 3), ('Home', 3), ('Build', 3), ('general', 2), ('design', 2), ('Renovations', 2), ('Modern', 2), ('General', 2), ('Design', 2), ('Country', 2), ('Contractors', 2), ('Contractor', 2), ('Builders,', 2), ('vision', 1), ('systems', 1), ('skyline', 1), ('pro', 1), ('home', 1), ('company', 1), ('builiding', 1), ('builder', 1), ('bay', 1), ('Yua', 1), ('Western', 1), ('West', 1), ('Welfring', 1), ('Vnace', 1), ('VMS', 1), ('Utopia', 1), ('Upgrades', 1), ('Uniluxe,', 1), ('Ulpio', 1), ('The', 1), ('Terry', 1), ('Sunrise', 1), ('Skyline', 1), ('Services', 1), ('S', 1), ('Roygbiv', 1), ('Renovation', 1), ('Remodeling', 1), ('Regel', 1), ('Redwood', 1), ('Rake', 1), ('Pro', 1), ('Prime', 1), ('Precision', 1), ('Power', 1), ('Plumbing', 1), ('Pacific', 1), ('One', 1), ('O', 1), ('Management', 1), ('MAI', 1), ('Lawjas', 1), ('Lacon', 1), ('LLC', 1), ('LK', 1), ('Kitchen', 1), ('Jimenez', 1), ('James', 1), ('J', 1), ('Iternational', 1), ('IBuilders', 1), ('Hua', 1), ('Homes', 1), ('Hilltop', 1), ('H', 1), ('Grid', 1), ('Grenon', 1), ('Green', 1), ('Giulani', 1), ('Gaylord', 1), ('Foundation', 1), ('Far', 1), ('Evergreen', 1), ('Energy', 1), ('Elite', 1), ('Dream', 1), ('Devcon', 1), ('Decor', 1), ('DI', 1), ('D', 1), ('Contracting', 1), ('Construction,', 1), ('Coastal', 1), ('Clarity', 1), ('Casa', 1), ('Caost', 1), ('Campisi', 1), ('Building', 1), ('Brown', 1), ('Brian', 1), ('Aria', 1), ('American', 1), ('Almaden', 1), ('All', 1), ('AZ', 1), ("AJ's", 1), ('ADG', 1), ('ABC', 1), ('AAA', 1), ('.', 1), ('-up', 1), (',', 1), ('&restoration', 1)]
# [('Jose,', 31), ('Morgan', 14), ('Palo', 12), ('Hill,', 12), ('Francisco,', 10), ('Alto,', 10), ('95124', 9), ('Blvd,', 6), ('Jose', 5), ('clara,', 4), ('Market', 4), ('Dr,', 4), ('Camden', 4), ('santa', 3), ('Rd,', 3), ('Mission', 3), ('Hill', 3), ('Campbell,', 3), ('95131', 3), ('st,', 2), ('Way,', 2), ('University', 2), ('Tech', 2), ('Sunset', 2), ('Sunnyvale,', 2), ('Ste', 2), ('Santa', 2), ('S', 2), ('N', 2), ('Main', 2), ('Emerson', 2), ('College', 2), ('Ca', 2